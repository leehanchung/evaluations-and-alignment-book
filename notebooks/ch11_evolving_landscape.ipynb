# %% [markdown]
# # Chapter 11: The Evolving Landscape of LLM Evaluation and Alignment
#
# This notebook accompanies Chapter 11 of *AI Evaluation and Alignments* (Manning Seminal Papers Series).

# %%
import pandas as pd
import matplotlib.pyplot as plt
