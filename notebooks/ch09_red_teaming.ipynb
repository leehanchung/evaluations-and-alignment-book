# %% [markdown]
# # Chapter 9: Advanced Alignment and Safety: Red Teaming and Beyond
#
# This notebook accompanies Chapter 9 of *AI Evaluation and Alignments* (Manning Seminal Papers Series).

# %%
from anthropic import Anthropic
from openai import OpenAI
