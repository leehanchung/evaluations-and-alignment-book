# %% [markdown]
# # Chapter 7: Reinforcement Learning from Human Preferences: The RLHF Foundation
#
# This notebook accompanies Chapter 7 of *AI Evaluation and Alignments* (Manning Seminal Papers Series).

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
