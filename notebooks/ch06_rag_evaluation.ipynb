# %% [markdown]
# # Chapter 6: Evaluating Retrieval-Augmented Generation (RAG)
#
# This notebook accompanies Chapter 6 of *AI Evaluation and Alignments* (Manning Seminal Papers Series).

# %%
import numpy as np
from datasets import load_dataset
