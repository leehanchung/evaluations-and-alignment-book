# %% [markdown]
# # Chapter 5: Detecting and Quantifying Hallucinations
#
# This notebook accompanies Chapter 5 of *AI Evaluation and Alignments* (Manning Seminal Papers Series).

# %%
import torch
from transformers import pipeline
